# %% [markdown]
# ## Software Use Case

# %% [markdown]
# Use case of inferring if a llm/chatbot helps the software engineering team to be more productible. If it worths its cost.

# %%
import os
os.chdir('/home/lawand/Experiments')
print(os.getcwd())
from utils.funcoes import generate_example
arestas = "U1 -> X, U1 -> Y, U2 -> D, U3 -> E, X -> Y, D -> X, D -> Y, E -> D"
generate_example(arestas, latent=["U1", "U2", "U3"], intervention=["X"], target="Y")
# Out:
# /home/lawand/Experiments
# 7
# 8
# U1 0
# U2 0
# U3 0
# X 2
# Y 2
# D 2
# E 2
# U1 X
# U1 Y
# U2 D
# U3 E
# X Y
# D X
# D Y
# E D

# %% [markdown]
# ### Data Generation

# %%
## Code to generate data
